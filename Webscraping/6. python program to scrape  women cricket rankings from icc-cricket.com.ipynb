# %%
#importing the required libraries
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
top10_teams = [] # empty list for store the

for i in soup.find_all('span',class_="u-hide-phablet"):
    top10_teams.append(i.text)
    
top10_teams
# Out:
# ['Australia',
#  'South Africa',
#  'England',
#  'India',
#  'Bangladesh',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Ireland',
#  'Sri Lanka',
#  'Zimbabwe',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
match= [] # empty list for store the

for i in soup.find_all('td',class_="rankings-block__banner--matches"):
    match.append(i.text)
    
match
# Out:
# ['17']

# %%
matches= [] # empty list for store the

for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    matches.append(i.text)
    
matches
# Out:
# ['19',
#  '2,307',
#  '18',
#  '2,148',
#  '17',
#  '1,899',
#  '5',
#  '475',
#  '19',
#  '1,668',
#  '19',
#  '1,658',
#  '19',
#  '1,304',
#  '5',
#  '240',
#  '5',
#  '233',
#  '8',
#  '0']

# %%
match.append(matches)

print(match)
# Out:
# ['17', ['19', '2,307', '18', '2,148', '17', '1,899', '5', '475', '19', '1,668', '19', '1,658', '19', '1,304', '5', '240', '5', '233', '8', '0']]

# %%
point = [] # empty list for store the

for i in soup.find_all('td',class_="rankings-block__banner--points"):
    point.append(i.text)
    
point
# Out:
# ['2,746']

# %%
points= [] # empty list for store the

for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    points.append(i.text)
    
points
# Out:
# ['19',
#  '2,307',
#  '18',
#  '2,148',
#  '17',
#  '1,899',
#  '5',
#  '475',
#  '19',
#  '1,668',
#  '19',
#  '1,658',
#  '19',
#  '1,304',
#  '5',
#  '240',
#  '5',
#  '233',
#  '8',
#  '0']

# %%
rating= [] # empty list for store the

for i in soup.find_all('td',class_="rankings-block__banner--rating u-text-right"):
    rating.append(i.text.replace('\n',''))
    
rating
# Out:
# ['                            162                            ']

# %%
ratings= [] # empty list for store the

for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    ratings.append(i.text)
    
ratings
# Out:
# ['121', '119', '112', '95', '88', '87', '69', '48', '47', '0']

# %%
rating.append(ratings)

print(rating)
# Out:
# ['                            162                            ', ['121', '119', '112', '95', '88', '87', '69', '48', '47', '0']]

# %% [markdown]
# # Top 10 ODI women along with the records of their team and rating¶

# %%
page= requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Batting | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Batting | Player Rankings | ICC" property="og:title"/>
# ...

# %%
player= [] # empty list for store the
for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    player.append(i.text)
    
player
# Out:
# ['Alyssa Healy']

# %%
players= [] # empty list for store the
for i in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    players.append(i.text.replace('\n',' '))
    
players
# Out:
# [' Mithali Raj ',
#  ' Lizelle Lee ',
#  ' Tammy Beaumont ',
#  ' Amy Satterthwaite ',
#  ' Smriti Mandhana ',
#  ' Meg Lanning ',
#  ' Beth Mooney ',
#  ' Heather Knight ',
#  ' Rachael Haynes ',
#  ' Stafanie Taylor ',
#  ' Ellyse Perry ',
#  ' Laura Wolvaardt ',
#  ' Natalie Sciver ',
#  ' Mignon du Preez ',
#  ' Deandra Dottin ',
#  ' Sophie Devine ',
#  ' Harmanpreet Kaur ',
#  ' Deepti Sharma ',
#  ' Amy Jones ',
#  ' Poonam Raut ',
#  ' Suzie Bates ',
#  ' Marizanne Kapp ',
#  ' Fargana Hoque ',
#  ' Aliya Riaz ',
#  ' Hayley Matthews ',
#  ' Ashleigh Gardner ',
#  ' Rumana Ahmed ',
#  ' Dane van Niekerk ',
#  ' Danielle Wyatt ',
#  ' Nahida Khan ',
#  ' Javeria Khan ',
#  ' Brooke Halliday ',
#  ' Gaby Lewis ',
#  ' Nida Dar ',
#  ' Maddie Green ',
#  ' Katherine Brunt ',
#  ' Lauren Winfield ',
#  ' Laura Delany ',
#  ' Katey Martin ',
#  ' Chloe-Lesleigh Tryon ',
#  ' Katie Perkins ',
#  ' Umaima Sohail ',
#  ' Sune Luus ',
#  ' Amelia Kerr ',
#  ' Jess Jonassen ',
# ...

# %%
player.append(players)
print(player)
# Out:
# ['Alyssa Healy', [' Mithali Raj ', ' Lizelle Lee ', ' Tammy Beaumont ', ' Amy Satterthwaite ', ' Smriti Mandhana ', ' Meg Lanning ', ' Beth Mooney ', ' Heather Knight ', ' Rachael Haynes ', ' Stafanie Taylor ', ' Ellyse Perry ', ' Laura Wolvaardt ', ' Natalie Sciver ', ' Mignon du Preez ', ' Deandra Dottin ', ' Sophie Devine ', ' Harmanpreet Kaur ', ' Deepti Sharma ', ' Amy Jones ', ' Poonam Raut ', ' Suzie Bates ', ' Marizanne Kapp ', ' Fargana Hoque ', ' Aliya Riaz ', ' Hayley Matthews ', ' Ashleigh Gardner ', ' Rumana Ahmed ', ' Dane van Niekerk ', ' Danielle Wyatt ', ' Nahida Khan ', ' Javeria Khan ', ' Brooke Halliday ', ' Gaby Lewis ', ' Nida Dar ', ' Maddie Green ', ' Katherine Brunt ', ' Lauren Winfield ', ' Laura Delany ', ' Katey Martin ', ' Chloe-Lesleigh Tryon ', ' Katie Perkins ', ' Umaima Sohail ', ' Sune Luus ', ' Amelia Kerr ', ' Jess Jonassen ', ' Tahlia McGrath ', ' Jhulan Goswami ', ' Trisha Chetty ', ' Shafali Verma ', ' Muneeba Ali ', ' Chedean Nation ', ' Leah P
# ...

# %%
batting_rating=[]
for i in soup.find_all('div',class_="rankings-block__banner--rating"):
    batting_rating.append(i.text)
    
batting_rating
# Out:
# ['750']

# %%
batting_ratings=[]
for i in soup.find_all('td',class_="table-body__cell rating"):
    batting_ratings.append(i.text)
    
batting_ratings
# Out:
# ['738',
#  '731',
#  '728',
#  '717',
#  '710',
#  '699',
#  '690',
#  '674',
#  '668',
#  '667',
#  '649',
#  '644',
#  '642',
#  '636',
#  '627',
#  '563',
#  '559',
#  '543',
#  '537',
#  '537',
#  '530',
#  '517',
#  '512',
#  '504',
#  '478',
#  '477',
#  '476',
#  '470',
#  '466',
#  '458',
#  '457',
#  '449',
#  '438',
#  '425',
#  '424',
#  '409',
#  '403',
#  '393',
#  '377',
#  '375',
#  '373',
#  '369',
#  '367',
#  '358',
#  '358',
#  '349',
#  '346',
#  '331',
#  '330',
#  '320',
#  '320',
#  '318',
#  '317',
#  '309',
#  '300',
#  '284',
#  '283',
#  '280',
#  '277',
#  '273',
#  '271',
#  '270',
#  '268',
#  '266',
#  '266',
#  '266',
#  '259',
#  '253',
#  '248',
#  '242',
#  '241',
#  '240',
#  '237',
#  '236',
#  '235',
#  '233',
#  '231',
#  '228',
#  '227',
#  '226',
#  '225',
#  '221',
#  '221',
#  '217',
#  '213',
#  '212',
#  '211',
#  '207',
#  '206',
#  '206',
#  '203',
#  '203',
#  '203',
#  '201',
#  '196',
#  '193',
#  '192',
#  '191',
#  '191']

# %%
batting_rating.append(batting_ratings)
batting_rating
# Out:
# ['750',
#  ['738',
#   '731',
#   '728',
#   '717',
#   '710',
#   '699',
#   '690',
#   '674',
#   '668',
#   '667',
#   '649',
#   '644',
#   '642',
#   '636',
#   '627',
#   '563',
#   '559',
#   '543',
#   '537',
#   '537',
#   '530',
#   '517',
#   '512',
#   '504',
#   '478',
#   '477',
#   '476',
#   '470',
#   '466',
#   '458',
#   '457',
#   '449',
#   '438',
#   '425',
#   '424',
#   '409',
#   '403',
#   '393',
#   '377',
#   '375',
#   '373',
#   '369',
#   '367',
#   '358',
#   '358',
#   '349',
#   '346',
#   '331',
#   '330',
#   '320',
#   '320',
#   '318',
#   '317',
#   '309',
#   '300',
#   '284',
#   '283',
#   '280',
#   '277',
#   '273',
#   '271',
#   '270',
#   '268',
#   '266',
#   '266',
#   '266',
#   '259',
#   '253',
#   '248',
#   '242',
#   '241',
#   '240',
#   '237',
#   '236',
#   '235',
#   '233',
#   '231',
#   '228',
#   '227',
#   '226',
#   '225',
#   '221',
#   '221',
#   '217',
#   '213',
#   '212',
#   '211',
#   '207',
#   '206',
#   '206',
# ...

# %% [markdown]
# # Top 10 ODI bowlers along with the records of their team and rating.¶

# %%
#importing the required libraries
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/bowling')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Bowling | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Bowling | Player Rankings | ICC" property="og:title"/>
# ...

# %%
bowler= [] # empty list for store the
for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    bowler.append(i.text)
    
bowler
# Out:
# ['Jess Jonassen']

# %%
bowlers= [] # empty list for store the
for i in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    bowlers.append(i.text.replace('\n',''))
    
bowlers
# Out:
# ['Jhulan Goswami',
#  'Megan Schutt',
#  'Sophie Ecclestone',
#  'Marizanne Kapp',
#  'Shabnim Ismail',
#  'Katherine Brunt',
#  'Ayabonga Khaka',
#  'Anya Shrubsole',
#  'Kate Cross',
#  'Hayley Matthews',
#  'Natalie Sciver',
#  'Poonam Yadav',
#  'Ashleigh Gardner',
#  'Leigh Kasperek',
#  'Ellyse Perry',
#  'Shikha Pandey',
#  'Lea Tahuhu',
#  'Deepti Sharma',
#  'Nashra Sandhu',
#  'Amelia Kerr',
#  'Dane van Niekerk',
#  'Rajeshwari Gayakwad',
#  'Georgia Wareham',
#  'Anisa Mohammed',
#  'Ekta Bisht',
#  'Shakera Selman',
#  'Sophie Devine',
#  'Shamilia Connell',
#  'Nida Dar',
#  'Khadija Tul Kubra',
#  'Anam Amin',
#  'Diana Baig',
#  'Sune Luus',
#  'Stafanie Taylor',
#  'Hannah Rowe',
#  'Salma Khatun',
#  'Rumana Ahmed',
#  'Nicola Carey',
#  'Nahida Akter',
#  'Tumi Sekhukhune',
#  'Jahanara Alam',
#  'Sophie Molineux',
#  'Masabata Klaas',
#  'Charlotte Dean',
#  'Jess Kerr',
#  'Holly Huddleston',
#  'Hayley Jensen',
#  'Darcie Brown',
#  'Sarah Glenn',
# ...

# %%
bowler.append(bowlers)
print(bowler)
# Out:
# ['Jess Jonassen', ['Jhulan Goswami', 'Megan Schutt', 'Sophie Ecclestone', 'Marizanne Kapp', 'Shabnim Ismail', 'Katherine Brunt', 'Ayabonga Khaka', 'Anya Shrubsole', 'Kate Cross', 'Hayley Matthews', 'Natalie Sciver', 'Poonam Yadav', 'Ashleigh Gardner', 'Leigh Kasperek', 'Ellyse Perry', 'Shikha Pandey', 'Lea Tahuhu', 'Deepti Sharma', 'Nashra Sandhu', 'Amelia Kerr', 'Dane van Niekerk', 'Rajeshwari Gayakwad', 'Georgia Wareham', 'Anisa Mohammed', 'Ekta Bisht', 'Shakera Selman', 'Sophie Devine', 'Shamilia Connell', 'Nida Dar', 'Khadija Tul Kubra', 'Anam Amin', 'Diana Baig', 'Sune Luus', 'Stafanie Taylor', 'Hannah Rowe', 'Salma Khatun', 'Rumana Ahmed', 'Nicola Carey', 'Nahida Akter', 'Tumi Sekhukhune', 'Jahanara Alam', 'Sophie Molineux', 'Masabata Klaas', 'Charlotte Dean', 'Jess Kerr', 'Holly Huddleston', 'Hayley Jensen', 'Darcie Brown', 'Sarah Glenn', 'Celeste Raack', 'Heather Knight', 'Annabel Sutherland', 'Sadia Iqbal', 'Nadine Klerk', 'Leah Paul', 'Chinelle Henry', 'Precious Marange', '
# ...

# %%
bowler_rating=[]
for i in soup.find_all('div',class_="rankings-block__banner--rating"):
    bowler_rating.append(i.text)
    
bowler_rating
# Out:
# ['760']

# %%
bowler_ratings=[]
for i in soup.find_all('td',class_="table-body__cell rating"):
    bowler_ratings.append(i.text)
    
bowler_ratings
# Out:
# ['727',
#  '717',
#  '701',
#  '687',
#  '685',
#  '666',
#  '635',
#  '598',
#  '589',
#  '587',
#  '580',
#  '578',
#  '577',
#  '574',
#  '563',
#  '561',
#  '557',
#  '551',
#  '550',
#  '540',
#  '540',
#  '539',
#  '502',
#  '475',
#  '466',
#  '466',
#  '442',
#  '441',
#  '439',
#  '433',
#  '428',
#  '424',
#  '422',
#  '422',
#  '412',
#  '411',
#  '410',
#  '407',
#  '387',
#  '384',
#  '372',
#  '365',
#  '353',
#  '351',
#  '349',
#  '336',
#  '312',
#  '304',
#  '296',
#  '295',
#  '290',
#  '280',
#  '265',
#  '258',
#  '253',
#  '252',
#  '250',
#  '249',
#  '249',
#  '246',
#  '245',
#  '239',
#  '238',
#  '237',
#  '227',
#  '223',
#  '222',
#  '215',
#  '211',
#  '210',
#  '206',
#  '206',
#  '206',
#  '200',
#  '196',
#  '193',
#  '191',
#  '188',
#  '188',
#  '187',
#  '183',
#  '179',
#  '178',
#  '177',
#  '175',
#  '175',
#  '173',
#  '172',
#  '166',
#  '166',
#  '162',
#  '162',
#  '157',
#  '154',
#  '137',
#  '137',
#  '136',
#  '119',
#  '119']

# %%
bowler_rating.append(bowler_ratings)
bowler_rating
# Out:
# ['727',
#  '717',
#  '701',
#  '687',
#  '685',
#  '666',
#  '635',
#  '598',
#  '589',
#  '587',
#  '580',
#  '578',
#  '577',
#  '574',
#  '563',
#  '561',
#  '557',
#  '551',
#  '550',
#  '540',
#  '540',
#  '539',
#  '502',
#  '475',
#  '466',
#  '466',
#  '442',
#  '441',
#  '439',
#  '433',
#  '428',
#  '424',
#  '422',
#  '422',
#  '412',
#  '411',
#  '410',
#  '407',
#  '387',
#  '384',
#  '372',
#  '365',
#  '353',
#  '351',
#  '349',
#  '336',
#  '312',
#  '304',
#  '296',
#  '295',
#  '290',
#  '280',
#  '265',
#  '258',
#  '253',
#  '252',
#  '250',
#  '249',
#  '249',
#  '246',
#  '245',
#  '239',
#  '238',
#  '237',
#  '227',
#  '223',
#  '222',
#  '215',
#  '211',
#  '210',
#  '206',
#  '206',
#  '206',
#  '200',
#  '196',
#  '193',
#  '191',
#  '188',
#  '188',
#  '187',
#  '183',
#  '179',
#  '178',
#  '177',
#  '175',
#  '175',
#  '173',
#  '172',
#  '166',
#  '166',
#  '162',
#  '162',
#  '157',
#  '154',
#  '137',
#  '137',
#  '136',
#  '119',
#  '119',
# ...
